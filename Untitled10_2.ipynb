# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin02232988/2025-BIG-DATA/blob/main/Untitled10_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = 'http://openapi.seoul.go.kr:8088/414d424556746f7036397a5a414f4f/json/SebcCollegeInfoKor/1/100//json/CardSubwayStatsNew/1/5/20220301'

# %%
response = requests.get(url)
print(response.content)
# Out:
# b'{"SebcCollegeInfoKor":{"list_total_count":64,"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4"},"row":[{"MAIN_KEY":"BE_LiST23-0034","YEAR":"2013","CATE1_NAME":"\xec\x9d\xbc\xeb\xb0\x98\xeb\x8c\x80\xed\x95\x99","NAME_KOR":"\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c\xeb\xa6\xbd\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","BRANCH":"\xeb\xb3\xb8\xea\xb5\x90","STATE":"\xea\xb8\xb0\xec\xa1\xb4","TYPE":"\xea\xb3\xb5\xeb\xa6\xbd","POSTCODE":"","ADD_KOR":"\xec\x84\x9c\xec\x9a\xb8 \xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac \xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c\xeb\xa6\xbd\xeb\x8c\x80\xeb\xa1\x9c 163 (\xec\xa0\x84\xeb\x86\x8d\xeb\x8f\x99 90\xeb\xb2\x88\xec\xa7\x80) ","ADD_KOR_ROAD":"","H_KOR_CITY":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","H_KOR_GU":"\xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac","H_KOR_DONG":"\xed\x9c\x98\xea\xb2\xbd2\xeb\x8f\x99","TEL":"02-6490-6114","FAX":"02-2210-5576","HP":"http://www.uos.ac.kr"},{"MAIN_KEY":"BE_LiST23-0035","YEAR":"2013","CATE1_NAME":"\xec\xa0\x84\xeb\xac\xb8\xeb\x8c\x80\xed\x95\x99(3\xeb\x85\x84\xec\xa0\x9c)","NAME_KOR":"\xec\x84\x9c\xec\x9a\xb8\xec\x97\xac\xec\x9e\x90\xea\xb0\x84\xed\x98\xb8\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","BRANCH":"\xeb\xb3\xb8\xea\xb5\x90","STATE":"\xea\xb8\xb0\xec\xa1\xb4","TYPE":"\xec\x82\xac\xeb\xa6\xbd","POSTCODE":"","ADD_KOR":"\xec\x84\x9c\xec\x9a\xb8 \xec\x84\x9c\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac \xed\x99\x8d\xec\xa0\x9c3\xeb\x8f\x99 \xec\x84\x9c\xec\x9a\xb8\xec\x97\xac\xec\x9e\x90\xea\xb0\x84\xed\x98\xb8\xeb\x8c\x80\xed\x95\x99","ADD_KOR_ROAD":"","H_KOR_CITY":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","H_KOR_GU":"\xec\x84\x9c\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac","H_KOR_DONG":"\xed\x99\x8d\xec\xa0\x9c2\xeb\x8f\x99","TEL":"02-2287-1700","FAX":"02-395-8018","HP":"http://www.snjc.ac.kr"},{"MAIN_KEY":"BE_LiST23-0036","YEAR":"2013","CATE1_NAME":"\xec\x9d\xbc\xeb\xb0\x98\xeb\x8c\x80\xed\x95\x99","NAME_KOR":"\xec\x84\x9c\xec\x9a\xb8\xec\x97\xac\xec\x9e\x90\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","BRANCH":"\xeb\xb3\xb8\xea\xb5\x90","STATE":"\xea\xb8\xb0\xec\xa1\xb4","TYPE":"\xec\x82\xac\xeb\xa6\xbd","POSTCODE":"","ADD_KOR":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xeb\x85\xb8\xec\x9b\x90\xea\xb5\xac \xed\x99\x94\xeb\x9e\x91\xeb\xa1\x9c 621 \xec\x84\x9c\xec\x9a\xb8\xec\x97\xac\xec\x9e\x90\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","ADD_KOR_ROAD":"","H_KOR_CITY":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","H_KOR_GU":"\xeb\x85\xb8\xec\x9b\x90\xea\xb5\xac","H_KOR_DONG":"\xea\xb3\xb5\xeb\xa6\x892\xeb\x8f\x99","TEL":"02-970-5114","FAX":"02-978-7931","HP":"http://www.swu.ac.kr"},{"MAIN_KEY":"BE_LiST23-0037","YEAR":"2013","CATE1_NAME":"\xec\xa0\x84\xeb\xac\xb8\xeb\x8c\x80\xed\x95\x99(2\xeb\x85\x84\xec\xa0\x9c)","NAME_KOR":"\xec\x84\x9c\xec\x9d\xbc\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","BRANCH":"\xeb\xb3\xb8\xea\xb5\x90","STATE":"\xed\x95\x99\xea\xb5\x90\xeb\xaa\x85 \xeb\xb3\x80\xea\xb2\xbd","TYPE":"\xec\x82\xac\xeb\xa6\xbd","POSTCODE":"","ADD_KOR":"\xec\x84\x9c\xec\x9a\xb8 \xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac \xec\x84\x9c\xec\x9d\xbc\xeb\x8c\x80\xed\x95\x99\xea\xb8\xb8 22(\xeb\xa9\xb4\xeb\xaa\xa9\xeb\x8f\x99 49-3) \xec\x84\x9c\xec\x9d\xbc\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","ADD_KOR_ROAD":"","H_KOR_CITY":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","H_KOR_GU":"\xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac","H_KOR_DONG":"\xeb\xa9\xb4\xeb\xaa\xa9\xec\xa0\x9c3.8\xeb\x8f\x99","TEL":"02-490-7300","FAX":"02-493-2576","HP":"http://www.seoil.ac.kr"},{"MAIN_KEY":"BE_LiST23-0038","YEAR":"2013","CATE1_NAME":"\xec\x9d\xbc\xeb\xb0\x98\xeb\x8c\x80\xed\x95\x99","NAME_KOR":"\xec\x84\xb1\xea\xb3\xb5\xed\x9a\x8c\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","BRANCH":"\xeb\xb3\xb8\xea\xb5\x90","STATE":"\xea\xb8\xb0\xec\xa1\xb4","TYPE":"\xec\x82\xac\xeb\xa6\xbd","POSTCODE":"","ADD_KOR":"\xec\x84\x9c\xec\x9a\xb8 \xea\xb5\xac\xeb\xa1\x9 ...

# %%
data = response.json()
data
# Out:
# {'SebcCollegeInfoKor': {'list_total_count': 64,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'MAIN_KEY': 'BE_LiST23-0034',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울시립대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '공립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 서울시립대로 163 (전농동 90번지) ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '휘경2동',
#     'TEL': '02-6490-6114',
#     'FAX': '02-2210-5576',
#     'HP': 'http://www.uos.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0035',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '서울여자간호대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 홍제3동 서울여자간호대학',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '홍제2동',
#     'TEL': '02-2287-1700',
#     'FAX': '02-395-8018',
#     'HP': 'http://www.snjc.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0036',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울특별시 노원구 화랑로 621 서울여자대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '노원구',
#     'H_KOR_DONG': '공릉2동',
#     'TEL': '02-970-5114',
#     'FAX': '02-978-7931',
#     'HP': 'http://www.swu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0037',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(2년제)',
#     'NAME_KOR': '서일대학교',
#     'BRANCH': '본교',
#     'STATE': '학교명 변경',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 중랑구 서일대학길 22(면목동 49-3) 서일대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '중랑구',
#     'H_KOR_DONG': '면목제3.8동',
#     'TEL': '02-490-7300',
#     'FAX': '02-493-2576',
#     'HP': 'http://www.seoil.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0038',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '성공회대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 구로구 항동 성공회대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '구로구',
#     'H_KOR_DONG': '오류2동',
#     'TEL': '02-2610-4142',
#     'FAX': '02-2610-4248',
#     'HP': 'http://www.skhu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0039',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '성균관대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 종로구 명륜동3가 성균관대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '종로구',
#     'H_KOR_DONG': '종로1.2.3.4가동',
#     'TEL': '02-760-0114',
#     'FAX': '',
#     'HP': 'http://www.skku.edu'},
#    {'MAIN_KEY': 'BE_LiST23-0040',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '성신여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성북구 동선동3가 성신여자대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성북구',
#     'H_KOR_DONG': '동선동',
#     'TEL': '02-920-7114',
#     'FAX': '02-920-2018',
#     'HP': 'http://www.sungshin.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0041',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '세종대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 광진구 군자동 세종대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '광진구',
#     'H_KOR_DONG': '군자동',
#     'TEL': '02-3408-3114',
#     'FAX': '02-3408-3906',
#     'HP': 'http://www.sejong.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0042',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '숙명여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 용산구 청파로47길 100 숙명여자대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '용산구',
#     'H_KOR_DONG': '청파동',
#     'TEL': '',
#     'FAX': '',
#     'HP': 'http://www.sookmyung.ac.kr/'},
#    {'MAIN_KEY': 'BE_LiST23-0043',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '숭실대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동작구 상도동 511 숭실대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동작구',
#     'H_KOR_DONG': '상도1동',
#     'TEL': '02-820-0114',
#     'FAX': '',
#     'HP': 'http://www.ssu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0044',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(2년제)',
#     'NAME_KOR': '숭의여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울특별시 중구 소파로2길 10(예장동)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '중구',
#     'H_KOR_DONG': '필동',
#     'TEL': '02-3708-9000',
#     'FAX': '02-773-2625',
#     'HP': 'http://www.sewc.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0045',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '연세대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 신촌동 연세대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '신촌동',
#     'TEL': '02-2123-2114',
#     'FAX': '02-392-0618',
#     'HP': 'http://www.yonsei.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0046',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '이화여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 대현동 11-1 이화여자대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '신촌동',
#     'TEL': '02-3277-2114',
#     'FAX': '02-393-5903',
#     'HP': 'http://www.ewha.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0047',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(2년제)',
#     'NAME_KOR': '인덕대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 노원구 초안산로 12',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '노원구',
#     'H_KOR_DONG': '월계2동',
#     'TEL': '02-950-7000',
#     'FAX': '02-906-5340',
#     'HP': 'http://www.induk.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0048',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '장로회신학대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 광진구 광장로 5길 25-1(광장동) 장로회신학대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '광진구',
#     'H_KOR_DONG': '광장동',
#     'TEL': '02-450-0700',
#     'FAX': '',
#     'HP': 'http://www.pcts.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0049',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '적십자간호대학',
#     'BRANCH': '본교',
#     'STATE': '폐교',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 종로구 경교장길8',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '종로구',
#     'H_KOR_DONG': '교남동',
#     'TEL': '02-3700-3600',
#     'FAX': '02-3700-3400',
#     'HP': 'http://redcross.cau.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0050',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '중앙대학교 서울캠퍼스',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동작구 흑석로 84',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동작구',
#     'H_KOR_DONG': '흑석동',
#     'TEL': '02-820-5114',
#     'FAX': '',
#     'HP': 'http://www.cau.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0051',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '총신대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동작구 사당동 산31-3',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동작구',
#     'H_KOR_DONG': '사당3동',
#     'TEL': '02-3479-0200',
#     'FAX': '02-536-2602',
#     'HP': 'http://www.chongshin.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0052',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '추계예술대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 북아현동 190-1 추계예술대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '충현동',
#     'TEL': '02-362-5700',
#     'FAX': '02-392-1777',
#     'HP': 'http://www.chugye.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0053',
#     'YEAR': '2013',
#     'CATE1_NAME': '방송통신대학',
#     'NAME_KOR': '한국방송통신대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '국립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 종로구 동숭동 한국방송통신대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '종로구',
#     'H_KOR_DONG': '이화동',
#     'TEL': '02-3668-4114',
#     'FAX': '02-744-5882',
#     'HP': 'http://www.knou.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0054',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '한국성서대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 노원구 상계7동 한국성서대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '노원구',
#     'H_KOR_DONG': '상계6.7동',
#     'TEL': '02-950-5401',
#     'FAX': '02-950-5411',
#     'HP': 'http://www.bible.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0055',
#     'YEAR': '2013',
#     'CATE1_NAME': '각종대학(대학)',
#     'NAME_KOR': '한국예술종합학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '특별법국립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성북구 석관동 ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성북구',
#     'H_KOR_DONG': '석관동',
#     'TEL': '',
#     'FAX': '',
#     'HP': ''},
#    {'MAIN_KEY': 'BE_LiST23-0056',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '한국외국어대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 이문로 107',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '이문1동',
#     'TEL': '02-2173-2114',
#     'FAX': '',
#     'HP': 'http://www.hufs.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0057',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '한국체육대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '국립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 송파구 오륜동 한국체육대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '송파구',
#     'H_KOR_DONG': '오륜동',
#     'TEL': '02-410-6564',
#     'FAX': '02-410-6569',
#     'HP': 'http://www.knsu.ac.kr/'},
#    {'MAIN_KEY': 'BE_LiST23-0058',
#     'YEAR': '2013',
#     'CATE1_NAME': '기능대학',
#     'NAME_KOR': '한국폴리텍 I 대학 서울강서캠퍼스',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 강서구 화곡동 산60-1',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '강서구',
#     'H_KOR_DONG': '우장산동',
#     'TEL': '02-2186-5800',
#     'FAX': '02-2186-5819',
#     'HP': 'http://kangseo.kopo.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0059',
#     'YEAR': '2013',
#     'CATE1_NAME': '기능대학',
#     'NAME_KOR': '한국폴리텍Ⅰ대학 서울정수캠퍼스',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 용산구 보광로 73(보광동 238)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '용산구',
#     'H_KOR_DONG': '보광동',
#     'TEL': '02-2001-4000',
#     'FAX': '02-2001-4119',
#     'HP': 'http://jungsu.kopo.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0060',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '한성대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성북구 삼선동3가 389 한성대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성북구',
#     'H_KOR_DONG': '삼선동',
#     'TEL': '02-760-4231',
#     'FAX': '02-745-8943',
#     'HP': 'http://www.hansung.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0061',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '한양대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울특별시 성동구 왕십리로 222 ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성동구',
#     'H_KOR_DONG': '사근동',
#     'TEL': '02-2220-0114',
#     'FAX': '',
#     'HP': 'http://www.hanyang.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0062',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(2년제)',
#     'NAME_KOR': '한양여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성동구 행당동 살곶이길 200',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성동구',
#     'H_KOR_DONG': '사근동',
#     'TEL': '02-2290-2114',
#     'FAX': '02-2291-6111',
#     'HP': 'http://www.hywoman.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0063',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '한영신학대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 구로구 경인로 290-42  한영신학대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '구로구',
#     'H_KOR_DONG': '개봉1동',
#     'TEL': '02-2067-4500',
#     'FAX': '02-2616-4102',
#     'HP': 'http://www.hytu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0064',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '홍익대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울특별시 마포구 와우산로 94(상수동)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '마포구',
#     'H_KOR_DONG': '서강동',
#     'TEL': '02-320-1114',
#     'FAX': '02-320-1122',
#     'HP': 'http://www.hongik.ac.kr/'},
#    {'MAIN_KEY': 'BE_LiST23-0001',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '가톨릭대학교',
#     'BRANCH': '제2캠퍼스',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서초구 반포동 505',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서초구',
#     'H_KOR_DONG': '반포4동',
#     'TEL': '',
#     'FAX': '',
#     'HP': 'http://songeui.catholic.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0002',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '가톨릭대학교',
#     'BRANCH': '제3캠퍼스',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 종로구 창경궁로 296-12(혜화동) ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '종로구',
#     'H_KOR_DONG': '이화동',
#     'TEL': '02-740-9714',
#     'FAX': '02-741-2801',
#     'HP': 'http://catholic.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0003',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '감리교신학대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 냉천동 감리교신학대학',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '천연동',
#     'TEL': '02-361-9114',
#     'FAX': '02-361-9299',
#     'HP': 'http://www.mtu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0004',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '건국대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 광진구 화양동',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '광진구',
#     'H_KOR_DONG': '화양동',
#     'TEL': '02-450-3114',
#     'FAX': '02-450-4126',
#     'HP': 'http://www.konkuk.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0005',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '경기대학교',
#     'BRANCH': '제2캠퍼스',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 경기대로9길 24 경기대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '충현동',
#     'TEL': '02-390-5114',
#     'FAX': '031-249-8718',
#     'HP': 'http://www.kyonggi.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0006',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '경희대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 회기동 경희대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '회기동',
#     'TEL': '02-961-0114',
#     'FAX': '02-961-0930',
#     'HP': 'http://www.khu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0007',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '고려대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성북구 안암동 고려대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성북구',
#     'H_KOR_DONG': '안암동',
#     'TEL': '02-3290-1114',
#     'FAX': '',
#     'HP': 'http://www.korea.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0008',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '광운대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울특별시 노원구 월계동 447-1',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '노원구',
#     'H_KOR_DONG': '월계1동',
#     'TEL': '',
#     'FAX': '',
#     'HP': 'http://www.kw.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0009',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '국민대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성북구 정릉3동 국민대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성북구',
#     'H_KOR_DONG': '정릉3동',
#     'TEL': '02-910-4114',
#     'FAX': '',
#     'HP': 'http://www.kookmin.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0010',
#     'YEAR': '2013',
#     'CATE1_NAME': '전공대학',
#     'NAME_KOR': '국제예술대학',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 강남구 논현동 79',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '강남구',
#     'H_KOR_DONG': '논현2동',
#     'TEL': '02-542-8197',
#     'FAX': '02-517-1392',
#     'HP': 'http://www.kica.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0011',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '그리스도대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 강서구 화곡6동 그리스도대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '강서구',
#     'H_KOR_DONG': '화곡본동',
#     'TEL': '02-2600-2400',
#     'FAX': '02-2698-8876',
#     'HP': 'http://kcu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0012',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '덕성여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울특별시 도봉구 삼양로 144길 33',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '도봉구',
#     'H_KOR_DONG': '쌍문1동',
#     'TEL': '02-901-8000',
#     'FAX': '',
#     'HP': 'http://www.duksung.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0013',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '동국대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 중구 필동3가 동국대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '중구',
#     'H_KOR_DONG': '필동',
#     'TEL': '02-2260-3114',
#     'FAX': '02-2277-1274',
#     'HP': 'http://www.dongguk.edu'},
#    {'MAIN_KEY': 'BE_LiST23-0014',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '동덕여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성북구 하월곡2동 동덕여자대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성북구',
#     'H_KOR_DONG': '삼선동',
#     'TEL': '02-940-4000',
#     'FAX': '02-940-4182',
#     'HP': 'http://www.dongduk.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0015',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '동양미래대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울시 구로구 경인로 445 동양미래대학교 (고척동 62-160)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '구로구',
#     'H_KOR_DONG': '고척1동',
#     'TEL': '02-2610-1700',
#     'FAX': '02-2688-5494',
#     'HP': 'http://www.dongyang.ac.kr/'},
#    {'MAIN_KEY': 'BE_LiST23-0016',
#     'YEAR': '2013',
#     'CATE1_NAME': '사이버대학(대학)',
#     'NAME_KOR': '디지털서울문화예술대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울시 서대문구 통일로 37길 60 (홍제동 318-18)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '홍제1동',
#     'TEL': '02-2287-0222',
#     'FAX': '02-379-8828',
#     'HP': 'http://www.scau.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0017',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '명지대학교 인문캠퍼스',
#     'BRANCH': '제2캠퍼스',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 남가좌동 50-3',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '남가좌2동',
#     'TEL': '02-300-1556',
#     'FAX': '02-300-1556',
#     'HP': 'http://www.mju.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0018',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '명지전문대학',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 가좌로 134 명지전문대학 ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '홍은2동',
#     'TEL': '02-300-1000',
#     'FAX': '02-304-4832',
#     'HP': 'http://www.mjc.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0019',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '배화여자대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 종로구 필운대로 1길 34 배화여자대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '종로구',
#     'H_KOR_DONG': '청운효자동',
#     'TEL': '02-399-0700',
#     'FAX': '02-737-8431',
#     'HP': 'http://www.baewha.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0020',
#     'YEAR': '2013',
#     'CATE1_NAME': '전공대학',
#     'NAME_KOR': '백석예술대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서초구 방배로9길 23 백석예술대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서초구',
#     'H_KOR_DONG': '방배3동',
#     'TEL': '02-520-0700',
#     'FAX': '02-520-0879',
#     'HP': 'http://www.bau.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0021',
#     'YEAR': '2013',
#     'CATE1_NAME': '사이버대학(대학)',
#     'NAME_KOR': '사이버한국외국어대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 이문동 한국외국어대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '이문1동',
#     'TEL': '02-2173-2580',
#     'FAX': '02-966-6183',
#     'HP': 'http://www.cufs.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0022',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '삼육대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울시 노원구 화랑로 815(공릉2동 26-21)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '노원구',
#     'H_KOR_DONG': '공릉2동',
#     'TEL': '02-3399-3636',
#     'FAX': '02-979-5318',
#     'HP': 'http://www.syu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0023',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '삼육보건대학교',
#     'BRANCH': '본교',
#     'STATE': '학교명 변경',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 휘경2동',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '휘경2동',
#     'TEL': '02-2212-0082',
#     'FAX': '02-2215-2380',
#     'HP': 'http://www.shu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0024',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '상명대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 종로구 홍지동 상명대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '종로구',
#     'H_KOR_DONG': '부암동',
#     'TEL': '02-2287-5114',
#     'FAX': '02-2287-0031',
#     'HP': 'http://www.smu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0025',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서강대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 마포구 신수동 서강대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '마포구',
#     'H_KOR_DONG': '대흥동',
#     'TEL': '02-705-8114',
#     'FAX': '',
#     'HP': 'http://www.sogang.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0026',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서경대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 성북구 정릉4동 서경대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '성북구',
#     'H_KOR_DONG': '정릉3동',
#     'TEL': '02-940-7114',
#     'FAX': '02-919-0345',
#     'HP': 'http://www.skuniv.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0027',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울과학기술대학교',
#     'BRANCH': '본교',
#     'STATE': '학제 변경',
#     'TYPE': '국립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 노원구 공릉로 232 (공릉동 172)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '노원구',
#     'H_KOR_DONG': '공릉2동',
#     'TEL': '02-970-6114',
#     'FAX': '02-970-6088',
#     'HP': 'http://www.seoultech.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0028',
#     'YEAR': '2013',
#     'CATE1_NAME': '산업대학',
#     'NAME_KOR': '서울과학기술대학교',
#     'BRANCH': '본교',
#     'STATE': '폐교',
#     'TYPE': '국립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울시 노원구 공릉로 232 서울과학기술대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '노원구',
#     'H_KOR_DONG': '공릉2동',
#     'TEL': '02-970-6114',
#     'FAX': '02-975-8110',
#     'HP': 'http://www.seoultech.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0029',
#     'YEAR': '2013',
#     'CATE1_NAME': '교육대학',
#     'NAME_KOR': '서울교육대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '국립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서초구 서초중앙로 96(서초동 1650)',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서초구',
#     'H_KOR_DONG': '서초1동',
#     'TEL': '02-3475-2114',
#     'FAX': '02-581-7711',
#     'HP': 'http://www.snue.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0030',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울기독대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 은평구 갈현로 4길 26-2호',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '은평구',
#     'H_KOR_DONG': '신사1동',
#     'TEL': '02-380-2500',
#     'FAX': '02-380-2535',
#     'HP': 'http://www.scu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0031',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '국립대법인',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 관악구 관악로 1 서울대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '관악구',
#     'H_KOR_DONG': '낙성대동',
#     'TEL': '02-880-5114',
#     'FAX': '02-885-5272',
#     'HP': 'http://www.snu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0032',
#     'YEAR': '2013',
#     'CATE1_NAME': '사이버대학(대학)',
#     'NAME_KOR': '서울디지털대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 마포구 도화동 560번지',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '마포구',
#     'H_KOR_DONG': '도화동',
#     'TEL': '02-1644-0982',
#     'FAX': '02-2128-3006',
#     'HP': 'http://www.sdu.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0033',
#     'YEAR': '2013',
#     'CATE1_NAME': '사이버대학(대학)',
#     'NAME_KOR': '서울사이버대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 강북구 솔매로49길 60(미아동 193-15) 서울사이버대학교',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '강북구',
#     'H_KOR_DONG': '미아동',
#     'TEL': '02-944-5000',
#     'FAX': '02-980-2222',
#     'HP': 'http://www.iscu.ac.kr'}]}}

# %%
import pandas as pd
temp = []

for d in data ['SebcCollegeInfoKor']['row']:
  temp.append(d)
uni = pd.DataFrame(temp)
uni
# Out:
#           MAIN_KEY  YEAR CATE1_NAME   NAME_KOR BRANCH   STATE   TYPE POSTCODE  \
# 0   BE_LiST23-0034  2013       일반대학    서울시립대학교     본교      기존     공립
# 1   BE_LiST23-0035  2013  전문대학(3년제)  서울여자간호대학교     본교      기존     사립
# 2   BE_LiST23-0036  2013       일반대학    서울여자대학교     본교      기존     사립
# 3   BE_LiST23-0037  2013  전문대학(2년제)      서일대학교     본교  학교명 변경     사립
# 4   BE_LiST23-0038  2013       일반대학     성공회대학교     본교      기존     사립
# ..             ...   ...        ...        ...    ...     ...    ...      ...
# 59  BE_LiST23-0029  2013       교육대학    서울교육대학교     본교      기존     국립
# 60  BE_LiST23-0030  2013       일반대학    서울기독대학교     본교      기존     사립
# 61  BE_LiST23-0031  2013       일반대학      서울대학교     본교      기존  국립대법인
# 62  BE_LiST23-0032  2013  사이버대학(대학)   서울디지털대학교     본교      기존     사립
# 63  BE_LiST23-0033  2013  사이버대학(대학)   서울사이버대학교     본교      기존     사립
#
#                                   ADD_KOR ADD_KOR_ROAD H_KOR_CITY H_KOR_GU  \
# 0          서울 동대문구 서울시립대로 163 (전농동 90번지)                    서울특별시     동대문구
# 1                   서울 서대문구 홍제3동 서울여자간호대학                   서울특별시     서대문구
# 2               서울특별시 노원구 화랑로 621 서울여자대학교                   서울특별시      노원구
# 3         서울 중랑구 서일대학길 22(면목동 49-3) 서일대학교                   서울특별시      중랑구
# 4                        서울 구로구 항동 성공회대학교                   서울특별시      구로구
# ..                                    ...          ...        ...      ...
# 59              서울 서초구 서초중앙로 96(서초동 1650)                   서울특별시      서초구
# 60                    서울 은평구 갈현로 4길 26-2호                   서울특별시      은평구
# 61                     서울 관악구 관악로 1 서울대학교                   서울특별시      관악구
# 62                       서울 마포구 도화동 560번지                   서울특별시      마포구
# 63  서울 강북구 솔매로49길 60(미아동 193-15) 서울사이버대학교                   서울특별시      강북구
#
#    H_KOR_DONG           TEL           FAX                      HP
# 0        휘경2동  02-6490-6114  02-2210-5576    http://www.uos.ac.kr
# 1        홍제2동  02-2287-1700   02-395-8018   http://www.snjc.ac.kr
# 2        공릉2동   02-970-5114   02-978-7931    http://www.swu.ac.kr
# 3     면목제3.8동   02-490-7300   02-493-2576  http://www.seoil.ac.kr
# 4        오류2동  02-2610-4142  02-2610-4248   http://www.skhu.ac.kr
# ..        ...           ...           ...                     ...
# 59       서초1동  02-3475-2114   02-581-7711   http://www.snue.ac.kr
# 60       신사1동   02-380-2500   02-380-2535    http://www.scu.ac.kr
# 61       낙성대동   02-880-5114   02-885-5272    http://www.snu.ac.kr
# 62        도화동  02-1644-0982  02-2128-3006    http://www.sdu.ac.kr
# 63        미아동   02-944-5000   02-980-2222   http://www.iscu.ac.kr
#
# [64 rows x 16 columns]

# %%
import requests

url = 'http://openapi.seoul.go.kr:8088/46487a6675746f703539496e596944/json/subwayStationMaster/1/100/'

response = requests.get(url)
print(response.content)
# Out:
# b'{"subwayStationMaster":{"list_total_count":909,"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4"},"row":[{"BLDN_ID":"0150","BLDN_NM":"\xec\x84\x9c\xec\x9a\xb8\xec\x97\xad","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.556228","LOT":"126.972135"},{"BLDN_ID":"0151","BLDN_NM":"\xec\x8b\x9c\xec\xb2\xad","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.565715","LOT":"126.977088"},{"BLDN_ID":"0152","BLDN_NM":"\xec\xa2\x85\xea\xb0\x81","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.570161","LOT":"126.982923"},{"BLDN_ID":"0153","BLDN_NM":"\xec\xa2\x85\xeb\xa1\x9c3\xea\xb0\x80","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.570406","LOT":"126.991847"},{"BLDN_ID":"0154","BLDN_NM":"\xec\xa2\x85\xeb\xa1\x9c5\xea\xb0\x80","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.570926","LOT":"127.001849"},{"BLDN_ID":"0155","BLDN_NM":"\xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.571687","LOT":"127.01093"},{"BLDN_ID":"0156","BLDN_NM":"\xec\x8b\xa0\xec\x84\xa4\xeb\x8f\x99","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.576048","LOT":"127.024634"},{"BLDN_ID":"0157","BLDN_NM":"\xec\xa0\x9c\xea\xb8\xb0\xeb\x8f\x99","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.578103","LOT":"127.034893"},{"BLDN_ID":"0158","BLDN_NM":"\xec\xb2\xad\xeb\x9f\x89\xeb\xa6\xac(\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c\xeb\xa6\xbd\xeb\x8c\x80\xec\x9e\x85\xea\xb5\xac)","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.579956","LOT":"127.044585"},{"BLDN_ID":"0159","BLDN_NM":"\xeb\x8f\x99\xeb\xac\x98\xec\x95\x9e","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.573197","LOT":"127.01648"},{"BLDN_ID":"0201","BLDN_NM":"\xec\x8b\x9c\xec\xb2\xad","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.563588","LOT":"126.975411"},{"BLDN_ID":"0202","BLDN_NM":"\xec\x9d\x84\xec\xa7\x80\xeb\xa1\x9c\xec\x9e\x85\xea\xb5\xac","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.566014","LOT":"126.982618"},{"BLDN_ID":"0203","BLDN_NM":"\xec\x9d\x84\xec\xa7\x80\xeb\xa1\x9c3\xea\xb0\x80","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.566306","LOT":"126.991696"},{"BLDN_ID":"0204","BLDN_NM":"\xec\x9d\x84\xec\xa7\x80\xeb\xa1\x9c4\xea\xb0\x80","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.566595","LOT":"126.997817"},{"BLDN_ID":"0205","BLDN_NM":"\xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8\xec\x97\xad\xec\x82\xac\xeb\xac\xb8\xed\x99\x94\xea\xb3\xb5\xec\x9b\x90","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.565613","LOT":"127.009054"},{"BLDN_ID":"0206","BLDN_NM":"\xec\x8b\xa0\xeb\x8b\xb9","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.56564","LOT":"127.019614"},{"BLDN_ID":"0207","BLDN_NM":"\xec\x83\x81\xec\x99\x95\xec\x8b\xad\xeb\xa6\xac","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.564354","LOT":"127.029354"},{"BLDN_ID":"0208","BLDN_NM":"\xec\x99\x95\xec\x8b\xad\xeb\xa6\xac(\xec\x84\xb1\xeb\x8f\x99\xea\xb5\xac\xec\xb2\xad)","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.561238","LOT":"127.036954"},{"BLDN_ID":"0209","BLDN_NM":"\xed\x95\x9c\xec\x96\x91\xeb\x8c\x80","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.555273","LOT":"127.043655"},{"BLDN_ID":"0210","BLDN_NM":"\xeb\x9a\x9d\xec\x84\xac","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.547184","LOT":"127.047367"},{"BLDN_ID":"0211","BLDN_NM":"\xec\x84\xb1\xec\x88\x98","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.544581","LOT":"127.055961"},{"BLDN_ID":"0212","BLDN_NM":"\xea\xb1\xb4\xeb\x8c\x80\xec\x9e\x85\xea\xb5\xac","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.540373","LOT":"127.069191"},{"BLDN_ID":"0213","BLDN_NM":"\xea\xb5\xac\xec\x9d\x98(\xea\xb4\x91\xec\xa7\x84\xea\xb5\xac\xec\xb2\xad)","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.537077","LOT":"127.085916"},{"BLDN_ID":"0214","BLDN_NM":"\xea\xb0\x95\xeb\xb3\x80(\xeb\x8f\x99\xec\x84\x9c\xec\x9a\xb8\xed\x84\xb0\xeb\xaf\xb8\xeb\x84\x90)","ROUTE":"2\xed\x98\xb8\xec\x84\xa0","LAT":"37.535095","LOT":"127.094681"},{"BLDN_ID":"0215","BLDN_NM":"\xec\x9e\xa0\xec\x8b\xa4\xeb\x82\x98\xeb\xa3\xa8","ROUTE":"2\xed\x98\xb ...

# %%
data = response.json()
data
# Out:
# {'subwayStationMaster': {'list_total_count': 909,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'BLDN_ID': '0150',
#     'BLDN_NM': '서울역',
#     'ROUTE': '1호선',
#     'LAT': '37.556228',
#     'LOT': '126.972135'},
#    {'BLDN_ID': '0151',
#     'BLDN_NM': '시청',
#     'ROUTE': '1호선',
#     'LAT': '37.565715',
#     'LOT': '126.977088'},
#    {'BLDN_ID': '0152',
#     'BLDN_NM': '종각',
#     'ROUTE': '1호선',
#     'LAT': '37.570161',
#     'LOT': '126.982923'},
#    {'BLDN_ID': '0153',
#     'BLDN_NM': '종로3가',
#     'ROUTE': '1호선',
#     'LAT': '37.570406',
#     'LOT': '126.991847'},
#    {'BLDN_ID': '0154',
#     'BLDN_NM': '종로5가',
#     'ROUTE': '1호선',
#     'LAT': '37.570926',
#     'LOT': '127.001849'},
#    {'BLDN_ID': '0155',
#     'BLDN_NM': '동대문',
#     'ROUTE': '1호선',
#     'LAT': '37.571687',
#     'LOT': '127.01093'},
#    {'BLDN_ID': '0156',
#     'BLDN_NM': '신설동',
#     'ROUTE': '1호선',
#     'LAT': '37.576048',
#     'LOT': '127.024634'},
#    {'BLDN_ID': '0157',
#     'BLDN_NM': '제기동',
#     'ROUTE': '1호선',
#     'LAT': '37.578103',
#     'LOT': '127.034893'},
#    {'BLDN_ID': '0158',
#     'BLDN_NM': '청량리(서울시립대입구)',
#     'ROUTE': '1호선',
#     'LAT': '37.579956',
#     'LOT': '127.044585'},
#    {'BLDN_ID': '0159',
#     'BLDN_NM': '동묘앞',
#     'ROUTE': '1호선',
#     'LAT': '37.573197',
#     'LOT': '127.01648'},
#    {'BLDN_ID': '0201',
#     'BLDN_NM': '시청',
#     'ROUTE': '2호선',
#     'LAT': '37.563588',
#     'LOT': '126.975411'},
#    {'BLDN_ID': '0202',
#     'BLDN_NM': '을지로입구',
#     'ROUTE': '2호선',
#     'LAT': '37.566014',
#     'LOT': '126.982618'},
#    {'BLDN_ID': '0203',
#     'BLDN_NM': '을지로3가',
#     'ROUTE': '2호선',
#     'LAT': '37.566306',
#     'LOT': '126.991696'},
#    {'BLDN_ID': '0204',
#     'BLDN_NM': '을지로4가',
#     'ROUTE': '2호선',
#     'LAT': '37.566595',
#     'LOT': '126.997817'},
#    {'BLDN_ID': '0205',
#     'BLDN_NM': '동대문역사문화공원',
#     'ROUTE': '2호선',
#     'LAT': '37.565613',
#     'LOT': '127.009054'},
#    {'BLDN_ID': '0206',
#     'BLDN_NM': '신당',
#     'ROUTE': '2호선',
#     'LAT': '37.56564',
#     'LOT': '127.019614'},
#    {'BLDN_ID': '0207',
#     'BLDN_NM': '상왕십리',
#     'ROUTE': '2호선',
#     'LAT': '37.564354',
#     'LOT': '127.029354'},
#    {'BLDN_ID': '0208',
#     'BLDN_NM': '왕십리(성동구청)',
#     'ROUTE': '2호선',
#     'LAT': '37.561238',
#     'LOT': '127.036954'},
#    {'BLDN_ID': '0209',
#     'BLDN_NM': '한양대',
#     'ROUTE': '2호선',
#     'LAT': '37.555273',
#     'LOT': '127.043655'},
#    {'BLDN_ID': '0210',
#     'BLDN_NM': '뚝섬',
#     'ROUTE': '2호선',
#     'LAT': '37.547184',
#     'LOT': '127.047367'},
#    {'BLDN_ID': '0211',
#     'BLDN_NM': '성수',
#     'ROUTE': '2호선',
#     'LAT': '37.544581',
#     'LOT': '127.055961'},
#    {'BLDN_ID': '0212',
#     'BLDN_NM': '건대입구',
#     'ROUTE': '2호선',
#     'LAT': '37.540373',
#     'LOT': '127.069191'},
#    {'BLDN_ID': '0213',
#     'BLDN_NM': '구의(광진구청)',
#     'ROUTE': '2호선',
#     'LAT': '37.537077',
#     'LOT': '127.085916'},
#    {'BLDN_ID': '0214',
#     'BLDN_NM': '강변(동서울터미널)',
#     'ROUTE': '2호선',
#     'LAT': '37.535095',
#     'LOT': '127.094681'},
#    {'BLDN_ID': '0215',
#     'BLDN_NM': '잠실나루',
#     'ROUTE': '2호선',
#     'LAT': '37.520733',
#     'LOT': '127.10379'},
#    {'BLDN_ID': '0216',
#     'BLDN_NM': '잠실(송파구청)',
#     'ROUTE': '2호선',
#     'LAT': '37.513262',
#     'LOT': '127.100159'},
#    {'BLDN_ID': '0217',
#     'BLDN_NM': '잠실새내',
#     'ROUTE': '2호선',
#     'LAT': '37.511687',
#     'LOT': '127.086162'},
#    {'BLDN_ID': '0218',
#     'BLDN_NM': '종합운동장',
#     'ROUTE': '2호선',
#     'LAT': '37.511022',
#     'LOT': '127.073704'},
#    {'BLDN_ID': '0219',
#     'BLDN_NM': '삼성(무역센터)',
#     'ROUTE': '2호선',
#     'LAT': '37.508844',
#     'LOT': '127.06316'},
#    {'BLDN_ID': '0220',
#     'BLDN_NM': '선릉',
#     'ROUTE': '2호선',
#     'LAT': '37.504286',
#     'LOT': '127.048203'},
#    {'BLDN_ID': '0221',
#     'BLDN_NM': '역삼',
#     'ROUTE': '2호선',
#     'LAT': '37.500622',
#     'LOT': '127.036456'},
#    {'BLDN_ID': '0222',
#     'BLDN_NM': '강남',
#     'ROUTE': '2호선',
#     'LAT': '37.49799',
#     'LOT': '127.027912'},
#    {'BLDN_ID': '0223',
#     'BLDN_NM': '교대(법원.검찰청)',
#     'ROUTE': '2호선',
#     'LAT': '37.493961',
#     'LOT': '127.014667'},
#    {'BLDN_ID': '0224',
#     'BLDN_NM': '서초',
#     'ROUTE': '2호선',
#     'LAT': '37.491897',
#     'LOT': '127.007917'},
#    {'BLDN_ID': '0225',
#     'BLDN_NM': '방배',
#     'ROUTE': '2호선',
#     'LAT': '37.481426',
#     'LOT': '126.997596'},
#    {'BLDN_ID': '0226',
#     'BLDN_NM': '사당',
#     'ROUTE': '2호선',
#     'LAT': '37.476538',
#     'LOT': '126.981544'},
#    {'BLDN_ID': '0227',
#     'BLDN_NM': '낙성대',
#     'ROUTE': '2호선',
#     'LAT': '37.47693',
#     'LOT': '126.963693'},
#    {'BLDN_ID': '0228',
#     'BLDN_NM': '서울대입구(관악구청)',
#     'ROUTE': '2호선',
#     'LAT': '37.481247',
#     'LOT': '126.952739'},
#    {'BLDN_ID': '0229',
#     'BLDN_NM': '봉천',
#     'ROUTE': '2호선',
#     'LAT': '37.482362',
#     'LOT': '126.941892'},
#    {'BLDN_ID': '0230',
#     'BLDN_NM': '신림',
#     'ROUTE': '2호선',
#     'LAT': '37.484201',
#     'LOT': '126.929715'},
#    {'BLDN_ID': '0231',
#     'BLDN_NM': '신대방',
#     'ROUTE': '2호선',
#     'LAT': '37.487462',
#     'LOT': '126.913149'},
#    {'BLDN_ID': '0232',
#     'BLDN_NM': '구로디지털단지',
#     'ROUTE': '2호선',
#     'LAT': '37.485266',
#     'LOT': '126.901401'},
#    {'BLDN_ID': '0233',
#     'BLDN_NM': '대림(구로구청)',
#     'ROUTE': '2호선',
#     'LAT': '37.493243',
#     'LOT': '126.894932'},
#    {'BLDN_ID': '0234',
#     'BLDN_NM': '신도림',
#     'ROUTE': '2호선',
#     'LAT': '37.508961',
#     'LOT': '126.891084'},
#    {'BLDN_ID': '0235',
#     'BLDN_NM': '문래',
#     'ROUTE': '2호선',
#     'LAT': '37.517933',
#     'LOT': '126.89476'},
#    {'BLDN_ID': '0236',
#     'BLDN_NM': '영등포구청',
#     'ROUTE': '2호선',
#     'LAT': '37.525706',
#     'LOT': '126.89661'},
#    {'BLDN_ID': '0237',
#     'BLDN_NM': '당산',
#     'ROUTE': '2호선',
#     'LAT': '37.534946',
#     'LOT': '126.902767'},
#    {'BLDN_ID': '0238',
#     'BLDN_NM': '합정',
#     'ROUTE': '2호선',
#     'LAT': '37.549457',
#     'LOT': '126.913808'},
#    {'BLDN_ID': '0239',
#     'BLDN_NM': '홍대입구',
#     'ROUTE': '2호선',
#     'LAT': '37.55679',
#     'LOT': '126.923708'},
#    {'BLDN_ID': '0240',
#     'BLDN_NM': '신촌',
#     'ROUTE': '2호선',
#     'LAT': '37.555131',
#     'LOT': '126.936926'},
#    {'BLDN_ID': '0241',
#     'BLDN_NM': '이대',
#     'ROUTE': '2호선',
#     'LAT': '37.556733',
#     'LOT': '126.946013'},
#    {'BLDN_ID': '0242',
#     'BLDN_NM': '아현',
#     'ROUTE': '2호선',
#     'LAT': '37.557345',
#     'LOT': '126.956141'},
#    {'BLDN_ID': '0243',
#     'BLDN_NM': '충정로(경기대입구)',
#     'ROUTE': '2호선',
#     'LAT': '37.559704',
#     'LOT': '126.964378'},
#    {'BLDN_ID': '0244',
#     'BLDN_NM': '용답',
#     'ROUTE': '2호선',
#     'LAT': '37.561904',
#     'LOT': '127.050899'},
#    {'BLDN_ID': '0245',
#     'BLDN_NM': '신답',
#     'ROUTE': '2호선',
#     'LAT': '37.57004',
#     'LOT': '127.046481'},
#    {'BLDN_ID': '0246',
#     'BLDN_NM': '신설동',
#     'ROUTE': '2호선',
#     'LAT': '37.574747',
#     'LOT': '127.024932'},
#    {'BLDN_ID': '0247',
#     'BLDN_NM': '도림천',
#     'ROUTE': '2호선',
#     'LAT': '37.514287',
#     'LOT': '126.882768'},
#    {'BLDN_ID': '0248',
#     'BLDN_NM': '양천구청',
#     'ROUTE': '2호선',
#     'LAT': '37.512398',
#     'LOT': '126.865819'},
#    {'BLDN_ID': '0249',
#     'BLDN_NM': '신정네거리',
#     'ROUTE': '2호선',
#     'LAT': '37.520074',
#     'LOT': '126.852912'},
#    {'BLDN_ID': '0250',
#     'BLDN_NM': '용두(동대문구청)',
#     'ROUTE': '2호선',
#     'LAT': '37.574028',
#     'LOT': '127.038091'},
#    {'BLDN_ID': '0309',
#     'BLDN_NM': '지축',
#     'ROUTE': '3호선',
#     'LAT': '37.648033',
#     'LOT': '126.913917'},
#    {'BLDN_ID': '0310',
#     'BLDN_NM': '구파발',
#     'ROUTE': '3호선',
#     'LAT': '37.636763',
#     'LOT': '126.918821'},
#    {'BLDN_ID': '0311',
#     'BLDN_NM': '연신내',
#     'ROUTE': '3호선',
#     'LAT': '37.619229',
#     'LOT': '126.921038'},
#    {'BLDN_ID': '0312',
#     'BLDN_NM': '불광',
#     'ROUTE': '3호선',
#     'LAT': '37.610553',
#     'LOT': '126.92982'},
#    {'BLDN_ID': '0313',
#     'BLDN_NM': '녹번',
#     'ROUTE': '3호선',
#     'LAT': '37.600927',
#     'LOT': '126.935756'},
#    {'BLDN_ID': '0314',
#     'BLDN_NM': '홍제',
#     'ROUTE': '3호선',
#     'LAT': '37.589066',
#     'LOT': '126.943736'},
#    {'BLDN_ID': '0315',
#     'BLDN_NM': '무악재',
#     'ROUTE': '3호선',
#     'LAT': '37.582299',
#     'LOT': '126.950291'},
#    {'BLDN_ID': '0316',
#     'BLDN_NM': '독립문',
#     'ROUTE': '3호선',
#     'LAT': '37.574571',
#     'LOT': '126.957748'},
#    {'BLDN_ID': '0317',
#     'BLDN_NM': '경복궁(정부서울청사)',
#     'ROUTE': '3호선',
#     'LAT': '37.575762',
#     'LOT': '126.97353'},
#    {'BLDN_ID': '0318',
#     'BLDN_NM': '안국',
#     'ROUTE': '3호선',
#     'LAT': '37.576477',
#     'LOT': '126.985443'},
#    {'BLDN_ID': '0319',
#     'BLDN_NM': '종로3가',
#     'ROUTE': '3호선',
#     'LAT': '37.571605',
#     'LOT': '126.991791'},
#    {'BLDN_ID': '0320',
#     'BLDN_NM': '을지로3가',
#     'ROUTE': '3호선',
#     'LAT': '37.566672',
#     'LOT': '126.992548'},
#    {'BLDN_ID': '0321',
#     'BLDN_NM': '충무로',
#     'ROUTE': '3호선',
#     'LAT': '37.56143',
#     'LOT': '126.994072'},
#    {'BLDN_ID': '0322',
#     'BLDN_NM': '동대입구',
#     'ROUTE': '3호선',
#     'LAT': '37.559052',
#     'LOT': '127.005602'},
#    {'BLDN_ID': '0323',
#     'BLDN_NM': '약수',
#     'ROUTE': '3호선',
#     'LAT': '37.554867',
#     'LOT': '127.010541'},
#    {'BLDN_ID': '0324',
#     'BLDN_NM': '금호',
#     'ROUTE': '3호선',
#     'LAT': '37.548034',
#     'LOT': '127.015872'},
#    {'BLDN_ID': '0325',
#     'BLDN_NM': '옥수',
#     'ROUTE': '3호선',
#     'LAT': '37.541684',
#     'LOT': '127.017269'},
#    {'BLDN_ID': '0326',
#     'BLDN_NM': '압구정',
#     'ROUTE': '3호선',
#     'LAT': '37.527072',
#     'LOT': '127.028461'},
#    {'BLDN_ID': '0327',
#     'BLDN_NM': '신사',
#     'ROUTE': '3호선',
#     'LAT': '37.516334',
#     'LOT': '127.020114'},
#    {'BLDN_ID': '0328',
#     'BLDN_NM': '잠원',
#     'ROUTE': '3호선',
#     'LAT': '37.512759',
#     'LOT': '127.01122'},
#    {'BLDN_ID': '0329',
#     'BLDN_NM': '고속터미널',
#     'ROUTE': '3호선',
#     'LAT': '37.504891',
#     'LOT': '127.004916'},
#    {'BLDN_ID': '0330',
#     'BLDN_NM': '교대(법원.검찰청)',
#     'ROUTE': '3호선',
#     'LAT': '37.493025',
#     'LOT': '127.013786'},
#    {'BLDN_ID': '0331',
#     'BLDN_NM': '남부터미널(예술의전당)',
#     'ROUTE': '3호선',
#     'LAT': '37.485013',
#     'LOT': '127.016189'},
#    {'BLDN_ID': '0332',
#     'BLDN_NM': '양재(서초구청)',
#     'ROUTE': '3호선',
#     'LAT': '37.484477',
#     'LOT': '127.033902'},
#    {'BLDN_ID': '0333',
#     'BLDN_NM': '매봉',
#     'ROUTE': '3호선',
#     'LAT': '37.486947',
#     'LOT': '127.046769'},
#    {'BLDN_ID': '0334',
#     'BLDN_NM': '도곡',
#     'ROUTE': '3호선',
#     'LAT': '37.490922',
#     'LOT': '127.055452'},
#    {'BLDN_ID': '0335',
#     'BLDN_NM': '대치',
#     'ROUTE': '3호선',
#     'LAT': '37.494612',
#     'LOT': '127.063642'},
#    {'BLDN_ID': '0336',
#     'BLDN_NM': '학여울',
#     'ROUTE': '3호선',
#     'LAT': '37.496663',
#     'LOT': '127.070594'},
#    {'BLDN_ID': '0337',
#     'BLDN_NM': '대청',
#     'ROUTE': '3호선',
#     'LAT': '37.493514',
#     'LOT': '127.079532'},
#    {'BLDN_ID': '0338',
#     'BLDN_NM': '일원',
#     'ROUTE': '3호선',
#     'LAT': '37.483681',
#     'LOT': '127.08439'},
#    {'BLDN_ID': '0339',
#     'BLDN_NM': '수서',
#     'ROUTE': '3호선',
#     'LAT': '37.487378',
#     'LOT': '127.101907'},
#    {'BLDN_ID': '0340',
#     'BLDN_NM': '가락시장',
#     'ROUTE': '3호선',
#     'LAT': '37.492245',
#     'LOT': '127.117757'},
#    {'BLDN_ID': '0341',
#     'BLDN_NM': '경찰병원',
#     'ROUTE': '3호선',
#     'LAT': '37.495918',
#     'LOT': '127.12454'},
#    {'BLDN_ID': '0342',
#     'BLDN_NM': '오금',
#     'ROUTE': '3호선',
#     'LAT': '37.502129',
#     'LOT': '127.128319'},
#    {'BLDN_ID': '0405',
#     'BLDN_NM': '진접',
#     'ROUTE': '진접선',
#     'LAT': '37.7205',
#     'LOT': '127.2034'},
#    {'BLDN_ID': '0406',
#     'BLDN_NM': '오남',
#     'ROUTE': '진접선',
#     'LAT': '37.705',
#     'LOT': '127.19281'},
#    {'BLDN_ID': '0408',
#     'BLDN_NM': '별내별가람',
#     'ROUTE': '진접선',
#     'LAT': '37.66778',
#     'LOT': '127.11581'},
#    {'BLDN_ID': '0409',
#     'BLDN_NM': '당고개',
#     'ROUTE': '4호선',
#     'LAT': '37.670272',
#     'LOT': '127.079066'},
#    {'BLDN_ID': '0410',
#     'BLDN_NM': '상계',
#     'ROUTE': '4호선',
#     'LAT': '37.660878',
#     'LOT': '127.073572'},
#    {'BLDN_ID': '0411',
#     'BLDN_NM': '노원',
#     'ROUTE': '4호선',
#     'LAT': '37.65627',
#     'LOT': '127.063276'}]}}

# %%
import pandas as pd
temp = []

for d in data ['subwayStationMaster']['row']:
  temp.append(d)
a = pd.DataFrame(temp)
a
# Out:
#    BLDN_ID BLDN_NM ROUTE        LAT         LOT
# 0     0150     서울역   1호선  37.556228  126.972135
# 1     0151      시청   1호선  37.565715  126.977088
# 2     0152      종각   1호선  37.570161  126.982923
# 3     0153    종로3가   1호선  37.570406  126.991847
# 4     0154    종로5가   1호선  37.570926  127.001849
# ..     ...     ...   ...        ...         ...
# 95    0406      오남   진접선     37.705   127.19281
# 96    0408   별내별가람   진접선   37.66778   127.11581
# 97    0409     당고개   4호선  37.670272  127.079066
# 98    0410      상계   4호선  37.660878  127.073572
# 99    0411      노원   4호선   37.65627  127.063276
#
# [100 rows x 5 columns]

# %%
import folium
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf9d5c8d335d6d7d1be91b75ae79ef20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf9d5c8d335d6d7d1be91b75ae79ef20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf9d5c8d335d6d7d1be91b75ae79ef20 = L.map(
#                 &quot;map_bf9d5c8d335d6d7d1be91b75ae79ef20&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db1d5fe21253deee39d674ab5328add3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db1d5fe21253deee39d674ab5328add3.addTo(map_bf9d5c8d335d6d7d1be91b75ae79ef20);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
b = folium.Map(location=[37.448028, 127.169366])
b
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56fdac9d2002a1de87095c613913f2e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56fdac9d2002a1de87095c613913f2e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56fdac9d2002a1de87095c613913f2e9 = L.map(
#                 &quot;map_56fdac9d2002a1de87095c613913f2e9&quot;,
#                 {
#                     center: [37.448028, 127.169366],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_418fc597a3daa6f7f8d8afb45c346c3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_418fc597a3daa6f7f8d8afb45c346c3b.addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for n, row in a.iterrows():
    mk = folium.Marker(location=[row["LAT"], row["LOT"]],
                       popup=folium.Popup(row["BLDN_NM"], max_width=200))
    mk.add_to(b)
b
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56fdac9d2002a1de87095c613913f2e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56fdac9d2002a1de87095c613913f2e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56fdac9d2002a1de87095c613913f2e9 = L.map(
#                 &quot;map_56fdac9d2002a1de87095c613913f2e9&quot;,
#                 {
#                     center: [37.448028, 127.169366],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_418fc597a3daa6f7f8d8afb45c346c3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_418fc597a3daa6f7f8d8afb45c346c3b.addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#             tile_layer_418fc597a3daa6f7f8d8afb45c346c3b.addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#             var marker_6a48e82f0e6a5e91566222bf44b2bcbb = L.marker(
#                 [37.556228, 126.972135],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_5b21e37bfe8c1ff7aaa28047fcbffe2f = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_75fd3ebf07ce0e1aed67dde7c8071b55 = $(`&lt;div id=&quot;html_75fd3ebf07ce0e1aed67dde7c8071b55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울역&lt;/div&gt;`)[0];
#                 popup_5b21e37bfe8c1ff7aaa28047fcbffe2f.setContent(html_75fd3ebf07ce0e1aed67dde7c8071b55);
#
#
#
#         marker_6a48e82f0e6a5e91566222bf44b2bcbb.bindPopup(popup_5b21e37bfe8c1ff7aaa28047fcbffe2f)
#         ;
#
#
#
#
#             var marker_bd2e567c3f479c8f282ea35a37dd7e8c = L.marker(
#                 [37.565715, 126.977088],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_ea288c2f93ae16987f6ef1f6e66b2369 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_6e91d22dd9458aea08915414f921b0cf = $(`&lt;div id=&quot;html_6e91d22dd9458aea08915414f921b0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;시청&lt;/div&gt;`)[0];
#                 popup_ea288c2f93ae16987f6ef1f6e66b2369.setContent(html_6e91d22dd9458aea08915414f921b0cf);
#
#
#
#         marker_bd2e567c3f479c8f282ea35a37dd7e8c.bindPopup(popup_ea288c2f93ae16987f6ef1f6e66b2369)
#         ;
#
#
#
#
#             var marker_9673a8c5c662a3fcba16e8658532c493 = L.marker(
#                 [37.570161, 126.982923],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_ae02346346a024bb67ffbd6f116132da = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_1e62dd96c339abf6c5697124da3ef5cf = $(`&lt;div id=&quot;html_1e62dd96c339abf6c5697124da3ef5cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종각&lt;/div&gt;`)[0];
#                 popup_ae02346346a024bb67ffbd6f116132da.setContent(html_1e62dd96c339abf6c5697124da3ef5cf);
#
#
#
#         marker_9673a8c5c662a3fcba16e8658532c493.bindPopup(popup_ae02346346a024bb67ffbd6f116132da)
#         ;
#
#
#
#
#             var marker_0a758dca085022667828f5e0cace9e66 = L.marker(
#                 [37.570406, 126.991847],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_dac3d88f247c4800abf6aed5f44030a7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_7d28fc245bb67ff714b96d6b79e5a02a = $(`&lt;div id=&quot;html_7d28fc245bb67ff714b96d6b79e5a02a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종로3가&lt;/div&gt;`)[0];
#                 popup_dac3d88f247c4800abf6aed5f44030a7.setContent(html_7d28fc245bb67ff714b96d6b79e5a02a);
#
#
#
#         marker_0a758dca085022667828f5e0cace9e66.bindPopup(popup_dac3d88f247c4800abf6aed5f44030a7)
#         ;
#
#
#
#
#             var marker_79a5a95b757708621110ef168ef70ba9 = L.marker(
#                 [37.570926, 127.001849],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_8de9d2f4ce3e31dc8dac11edf7d089f1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_3ff14acf3c718b8d1e7cd3a83ca5680d = $(`&lt;div id=&quot;html_3ff14acf3c718b8d1e7cd3a83ca5680d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종로5가&lt;/div&gt;`)[0];
#                 popup_8de9d2f4ce3e31dc8dac11edf7d089f1.setContent(html_3ff14acf3c718b8d1e7cd3a83ca5680d);
#
#
#
#         marker_79a5a95b757708621110ef168ef70ba9.bindPopup(popup_8de9d2f4ce3e31dc8dac11edf7d089f1)
#         ;
#
#
#
#
#             var marker_b65c4e4efa3b9b33fb9a914eae2b541d = L.marker(
#                 [37.571687, 127.01093],

# %%
from folium.plugins import MarkerCluster
mc = MarkerCluster().add_to(b)

for _, row in a.iterrows():
    folium.Marker(location=[row["LAT"], row["LOT"]],
                  popup=folium.Popup(row["BLDN_NM"], max_width=200)
                 ).add_to(mc)

b
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56fdac9d2002a1de87095c613913f2e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56fdac9d2002a1de87095c613913f2e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56fdac9d2002a1de87095c613913f2e9 = L.map(
#                 &quot;map_56fdac9d2002a1de87095c613913f2e9&quot;,
#                 {
#                     center: [37.448028, 127.169366],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_418fc597a3daa6f7f8d8afb45c346c3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_418fc597a3daa6f7f8d8afb45c346c3b.addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#             tile_layer_418fc597a3daa6f7f8d8afb45c346c3b.addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#             var marker_6a48e82f0e6a5e91566222bf44b2bcbb = L.marker(
#                 [37.556228, 126.972135],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_5b21e37bfe8c1ff7aaa28047fcbffe2f = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_75fd3ebf07ce0e1aed67dde7c8071b55 = $(`&lt;div id=&quot;html_75fd3ebf07ce0e1aed67dde7c8071b55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울역&lt;/div&gt;`)[0];
#                 popup_5b21e37bfe8c1ff7aaa28047fcbffe2f.setContent(html_75fd3ebf07ce0e1aed67dde7c8071b55);
#
#
#
#         marker_6a48e82f0e6a5e91566222bf44b2bcbb.bindPopup(popup_5b21e37bfe8c1ff7aaa28047fcbffe2f)
#         ;
#
#
#
#
#             var marker_bd2e567c3f479c8f282ea35a37dd7e8c = L.marker(
#                 [37.565715, 126.977088],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_ea288c2f93ae16987f6ef1f6e66b2369 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_6e91d22dd9458aea08915414f921b0cf = $(`&lt;div id=&quot;html_6e91d22dd9458aea08915414f921b0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;시청&lt;/div&gt;`)[0];
#                 popup_ea288c2f93ae16987f6ef1f6e66b2369.setContent(html_6e91d22dd9458aea08915414f921b0cf);
#
#
#
#         marker_bd2e567c3f479c8f282ea35a37dd7e8c.bindPopup(popup_ea288c2f93ae16987f6ef1f6e66b2369)
#         ;
#
#
#
#
#             var marker_9673a8c5c662a3fcba16e8658532c493 = L.marker(
#                 [37.570161, 126.982923],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_ae02346346a024bb67ffbd6f116132da = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_1e62dd96c339abf6c5697124da3ef5cf = $(`&lt;div id=&quot;html_1e62dd96c339abf6c5697124da3ef5cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종각&lt;/div&gt;`)[0];
#                 popup_ae02346346a024bb67ffbd6f116132da.setContent(html_1e62dd96c339abf6c5697124da3ef5cf);
#
#
#
#         marker_9673a8c5c662a3fcba16e8658532c493.bindPopup(popup_ae02346346a024bb67ffbd6f116132da)
#         ;
#
#
#
#
#             var marker_0a758dca085022667828f5e0cace9e66 = L.marker(
#                 [37.570406, 126.991847],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_dac3d88f247c4800abf6aed5f44030a7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_7d28fc245bb67ff714b96d6b79e5a02a = $(`&lt;div id=&quot;html_7d28fc245bb67ff714b96d6b79e5a02a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종로3가&lt;/div&gt;`)[0];
#                 popup_dac3d88f247c4800abf6aed5f44030a7.setContent(html_7d28fc245bb67ff714b96d6b79e5a02a);
#
#
#
#         marker_0a758dca085022667828f5e0cace9e66.bindPopup(popup_dac3d88f247c4800abf6aed5f44030a7)
#         ;
#
#
#
#
#             var marker_79a5a95b757708621110ef168ef70ba9 = L.marker(
#                 [37.570926, 127.001849],
#                 {
# }
#             ).addTo(map_56fdac9d2002a1de87095c613913f2e9);
#
#
#         var popup_8de9d2f4ce3e31dc8dac11edf7d089f1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_3ff14acf3c718b8d1e7cd3a83ca5680d = $(`&lt;div id=&quot;html_3ff14acf3c718b8d1e7cd3a83ca5680d&quot; style
