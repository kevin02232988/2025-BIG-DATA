# %%
data = pd.read_csv('공공자전거 대여소 정보(23.06월 기준).csv',encoding='EUC-KR')
data
# Out:
#       대여소\n번호            보관소(대여소)명  자치구                             상세주소  \
# 0         301          경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 1         302          경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤
# 2         303          광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원
# 3         305               종로구청 옆  종로구               서울특별시 종로구 세종로 84-1
# 4         307            서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞
# ...       ...                  ...  ...                              ...
# 2744     3699              상일파출소 옆  강동구                    강동구 상일동 520-1
# 2745     3700      강변그대가리버뷰 입구 맞은편  강동구                    강동구 천호동 250-7
# 2746     3701                방아삼거리  강동구                    강동구 둔촌동 118-2
# 2747     4951   강동농협 버스정류소 앞(광채빌라)  강동구                   강동구 암사동 488-21
# 2748     4952         천호시장 버스정류소 옆  강동구                  강동구 천호동 397-465
#
#              위도          경도      설치\n시기  거치\n대수  거치\n대수.1 운영\n방식
# ...

# %%
data['거치\n대수'].value_counts(dropna=False)
# Out:
# 거치\n대수
# NaN     1434
# 10.0     601
# 15.0     179
# 20.0     123
# 8.0       80
# 12.0      52
# 13.0      41
# 7.0       40
# 9.0       38
# 14.0      33
# 25.0      21
# 5.0       15
# 6.0       14
# 17.0      11
# 30.0      11
# 16.0      10
# 11.0       9
# 18.0       8
# 23.0       5
# 19.0       5
# 22.0       4
# 40.0       3
# 21.0       3
# 26.0       3
# 24.0       2
# 45.0       1
# 27.0       1
# 32.0       1
# 31.0       1
# Name: count, dtype: int64

# %%
data['거치\n대수'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2744     True
# 2745     True
# 2746     True
# 2747     True
# 2748     True
# Name: 거치\n대수, Length: 2749, dtype: bool

# %%
data.isna().sum()
# Out:
# 대여소\n번호         0
# 보관소(대여소)명       0
# 자치구             0
# 상세주소            0
# 위도              0
# 경도              0
# 설치\n시기          0
# 거치\n대수       1434
# 거치\n대수.1     1167
# 운영\n방식          0
# dtype: int64

# %%
data.dropna(subset=['거치\n대수','거치\n대수.1'])
# Out:
#       대여소\n번호     보관소(대여소)명   자치구                             상세주소         위도  \
# 0         301   경복궁역 7번출구 앞   종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞  37.575794
# 1         302   경복궁역 4번출구 뒤   종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤  37.575947
# 2         303   광화문역 1번출구 앞   종로구       서울특별시 종로구 세종대로 지하189 세종로공원  37.571770
# 3         305        종로구청 옆   종로구               서울특별시 종로구 세종로 84-1  37.572559
# 4         307     서울역사박물관 앞   종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞  37.570000
# ...       ...           ...   ...                              ...        ...
# 1843      270    증권거래소후문교차로  영등포구              서울특별시 영등포구 여의나루로 76  37.522343
# 1848      278    쌍용플레티넘오피스텔  영등포구                서울특별시 영등포구 도영로 18  37.507931
# 2290     2356          강남구청   강남구             서울특별시 강남구 학동로 지하 346  37.518070
# 2463     1271         송파도서관   송파구                서울특별시 송파구 동남로 263  37.499985
# 2657     1033     고덕동 아남아파트   강동구                    서울특별시 고덕동 673  37.557934
#
# ...

# %%
data.dropna(axis = 0,how = 'any')
# Out:
#       대여소\n번호     보관소(대여소)명   자치구                             상세주소         위도  \
# 0         301   경복궁역 7번출구 앞   종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞  37.575794
# 1         302   경복궁역 4번출구 뒤   종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤  37.575947
# 2         303   광화문역 1번출구 앞   종로구       서울특별시 종로구 세종대로 지하189 세종로공원  37.571770
# 3         305        종로구청 옆   종로구               서울특별시 종로구 세종로 84-1  37.572559
# 4         307     서울역사박물관 앞   종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞  37.570000
# ...       ...           ...   ...                              ...        ...
# 1843      270    증권거래소후문교차로  영등포구              서울특별시 영등포구 여의나루로 76  37.522343
# 1848      278    쌍용플레티넘오피스텔  영등포구                서울특별시 영등포구 도영로 18  37.507931
# 2290     2356          강남구청   강남구             서울특별시 강남구 학동로 지하 346  37.518070
# 2463     1271         송파도서관   송파구                서울특별시 송파구 동남로 263  37.499985
# 2657     1033     고덕동 아남아파트   강동구                    서울특별시 고덕동 673  37.557934
#
# ...

# %%
data['거치\n대수'].value_counts().sort_index()
# Out:
# 거치\n대수
# 5.0      15
# 6.0      14
# 7.0      40
# 8.0      80
# 9.0      38
# 10.0    601
# 11.0      9
# 12.0     52
# 13.0     41
# 14.0     33
# 15.0    179
# 16.0     10
# 17.0     11
# 18.0      8
# 19.0      5
# 20.0    123
# 21.0      3
# 22.0      4
# 23.0      5
# 24.0      2
# 25.0     21
# 26.0      3
# 27.0      1
# 30.0     11
# 31.0      1
# 32.0      1
# 40.0      3
# 45.0      1
# Name: count, dtype: int64

# %%
data.duplicated(['거치\n대수'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2744     True
# 2745     True
# 2746     True
# 2747     True
# 2748     True
# Length: 2749, dtype: bool

# %%
data.duplicated(['거치\n대수'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2744     True
# 2745     True
# 2746     True
# 2747     True
# 2748     True
# Length: 2749, dtype: bool

# %%
data.drop_duplicates(subset = ['거치\n대수','거치\n대수.1'],keep=False)
# Out:
#       대여소\n번호          보관소(대여소)명   자치구                                  상세주소  \
# 5         308          광화문 S타워 앞   종로구            서울특별시 종로구 새문안로 82 광화문S타워 앞
# 9         326         안국역 5번출구 앞   종로구         서울특별시 종로구 율곡로 지하62 안국역 5번출구 앞
# 20        342         대학로 마로니에공원   종로구          서울특별시 종로구 대학로 104 대학로 마로니에공원
# 21        343        예일빌딩(율곡로) 앞   종로구                      서울특별시 종로구 충신동 60
# 38        367        독립문역 3-1번출구   종로구        서울특별시 종로구 무악동 41-7 독립문역 3번출구 뒤
# 50        450            효자동 삼거리   종로구      서울특별시 종로구 효자로13길 45 종로구 궁정동 98-2
# 58        458          광화문역 5번출구   종로구              서울특별시 종로구 세종대로 152 일민미술관
# 103       300              정동사거리    중구                서울특별시 중구 정동길 2-1 정동사거리
# 104       310             청계광장 옆    중구              서울특별시 중구 세종대로 136 청계광장 옆
# 106       320      을지로입구역 4번출구 앞    중구              서울특별시 중구 을지로 55 명동금융센터 앞
# 203       815     LIG강촌아파트 103동앞   용산구     서울특별시 용산구 이촌동301-5 LIG강촌아파트 103동앞
# ...
